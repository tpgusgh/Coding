# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv('/content/drive/MyDrive/2302김현호 데이터분석/데이터들/커피.csv')
df
# Out:
#       메뉴    가격  칼로리
# 0  아메리카노  4500   10
# 1   카페라떼  5000  110
# 2   카페모카  5500  250
# 3   카푸치노  5000  110
# 4  에스프레소  4000   20
# 5    밀크티  5900  210
# 6     녹차  5300    0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   메뉴      7 non-null      object
#  1   가격      7 non-null      int64
#  2   칼로리     7 non-null      int64
# dtypes: int64(2), object(1)
# memory usage: 300.0+ bytes

# %%
df.shape
# Out:
# (7, 3)

# %%
df.head()
# Out:
#       메뉴    가격  칼로리
# 0  아메리카노  4500   10
# 1   카페라떼  5000  110
# 2   카페모카  5500  250
# 3   카푸치노  5000  110
# 4  에스프레소  4000   20

# %%
df.head(2)
# Out:
#       메뉴    가격  칼로리
# 0  아메리카노  4500   10
# 1   카페라떼  5000  110

# %%
df.tail(1)
# Out:
#    메뉴    가격  칼로리
# 6  녹차  5300    0

# %%
df.corr(numeric_only=True)
# Out:
#            가격       칼로리
# 가격   1.000000  0.713227
# 칼로리  0.713227  1.000000

# %%
df.nunique()
# Out:
# 메뉴     7
# 가격     6
# 칼로리    6
# dtype: int64

# %%
df['메뉴'].unique()
# Out:
# array(['아메리카노', '카페라떼', '카페모카', '카푸치노', '에스프레소', '밀크티', '녹차'],
#       dtype=object)

# %%
df['칼로리'].unique()
# Out:
# array([ 10, 110, 250,  20, 210,   0])

# %%
df['가격'].unique()
# Out:
# array([4500, 5000, 5500, 4000, 5900, 5300])

# %%
df['메뉴'].value_counts()
# Out:
# 메뉴
# 아메리카노    1
# 카페라떼     1
# 카페모카     1
# 카푸치노     1
# 에스프레소    1
# 밀크티      1
# 녹차       1
# Name: count, dtype: int64

# %%
df['가격'].value_counts()
# Out:
# 가격
# 5000    2
# 4500    1
# 5500    1
# 4000    1
# 5900    1
# 5300    1
# Name: count, dtype: int64

# %%
df['칼로리'].value_counts()
# Out:
# 칼로리
# 110    2
# 10     1
# 250    1
# 20     1
# 210    1
# 0      1
# Name: count, dtype: int64

# %%
df['가격'].sum()
# Out:
# np.int64(35200)

# %%
df.describe()
# Out:
#                 가격         칼로리
# count     7.000000    7.000000
# mean   5028.571429  101.428571
# std     631.702160   99.402980
# min    4000.000000    0.000000
# 25%    4750.000000   15.000000
# 50%    5000.000000  110.000000
# 75%    5400.000000  160.000000
# max    5900.000000  250.000000

# %%
df.describe(include='O')
# Out:
#            메뉴
# count       7
# unique      7
# top     아메리카노
# freq        1

# %%
dict_data = {'car':['Sedan','SUV','Sedan','SUV','SUV','SUV','Sedan','Sedan','Sedan','Sedan','Sedan'], 'size':['S','M','S','S','M','M','L','S','S','M','S']}
df1 = pd.DataFrame(dict_data)
df1.to_csv('car.csv' ,index=False)

# %%
df2 = pd.read_csv('/content/drive/MyDrive/2302김현호 데이터분석/데이터들/car.csv'  )

# %%
df2
# Out:
#     Unnamed: 0    car size
# 0            0  Sedan    S
# 1            1    SUV    M
# 2            2  Sedan    S
# 3            3    SUV    S
# 4            4    SUV    M
# 5            5    SUV    M
# 6            6  Sedan    L
# 7            7  Sedan    S
# 8            8  Sedan    S
# 9            9  Sedan    M
# 10          10  Sedan    S

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11 entries, 0 to 10
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   car     11 non-null     object
#  1   size    11 non-null     object
# dtypes: object(2)
# memory usage: 308.0+ bytes

# %%
df1.head()
# Out:
#      car size
# 0  Sedan    S
# 1    SUV    M
# 2  Sedan    S
# 3    SUV    S
# 4    SUV    M

# %%
df1.nunique()
# Out:
# car     2
# size    3
# dtype: int64

# %%
df2['car'].unique()
# Out:
# array(['Sedan', 'SUV'], dtype=object)

# %%
df2['size'].unique()
# Out:
# array(['S', 'M', 'L'], dtype=object)

# %%
df2['car'].value_counts()
# Out:
# car
# Sedan    7
# SUV      4
# Name: count, dtype: int64

# %%
df2['size'].value_counts()
# Out:
# size
# S    6
# M    4
# L    1
# Name: count, dtype: int64

# %%
df.describe(include='O')
# Out:
#            메뉴
# count       7
# unique      7
# top     아메리카노
# freq        1

# %%
df['가격']=df['가격'].astype('float')

# %%
df
# Out:
#       메뉴      가격  칼로리
# 0  아메리카노  4500.0   10
# 1   카페라떼  5000.0  110
# 2   카페모카  5500.0  250
# 3   카푸치노  5000.0  110
# 4  에스프레소  4000.0   20
# 5    밀크티  5900.0  210
# 6     녹차  5300.0    0

# %%
df['가격']=df['가격'].astype('object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   메뉴      7 non-null      object
#  1   가격      7 non-null      object
#  2   칼로리     7 non-null      int64
# dtypes: int64(1), object(2)
# memory usage: 300.0+ bytes

# %%
df['칼로리']=df['칼로리'].astype('float')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   메뉴      7 non-null      object
#  1   가격      7 non-null      object
#  2   칼로리     7 non-null      float64
# dtypes: float64(1), object(2)
# memory usage: 300.0+ bytes

# %%
df['메뉴']=df['메뉴'].astype('int')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-79-b1b618822d46> in <cell line: 0>()
# ----> 1 df['메뉴']=df['메뉴'].astype('int')
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    6641         else:
#    6642             # else, only a single dtype is given
# -> 6643             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6644             res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6645             return res.__finalize__(self, method="astype")
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/internals/managers.py in astype(self, dtype, copy, errors)
#     428             copy = False
#     429
# --> 430         return self.apply(
#     431             "astype",
#     432             dtype=dtype,
#
# ...

# %%
print(f"상처를 치료해줄 사람 어디 없나 가만히 놔두다간 끊임없이 덧나 사랑도 사람도 너무나도 겁나 혼자인게 무서워 난 잊혀질까 두려워 상처를 치료해줄 사람 어디 없나 가만히 놔두다간 끊임없이 덧나 사랑도 사람도 너무나도 겁나 혼자인게 무서워 난 잊혀질까 두려워 언제나 외톨이 맘의 문을 닫고 슬픔을 등에 지고 살아가는 바보 두 눈을 감고 두 귀를 막고 캄캄한 어둠속에 내 자신을 가둬 365일 1년 내내 방황하는 내 영혼의 조작 키를 잡은 Jack Sparrow 몰아치는 Hurricane 졸라매는 허리끈에 방향감을 상실하고 길을 잃은 소리꾼 내 안에 숨어 있는 또 다른 나와 싸워 그녀가 떠나갈때 내게 말했었지 너는 곁에 있어도 있는 게 아닌것 같다고 만지면 베어버리는 칼날같은 사람 심장이 얼어붙은 차가웠던 사랑 그래 1분 1초가 사는게 사는게 아냐 매일 매일이 너무나 두려워 Maider누가 날 좀 꺼내줘 언제나 외톨이 맘의 문을 닫고 슬픔을 등에 지고 살아가는 바보 두 눈을 감고 두 귀를 막고 캄캄한 어둠속에 내 자신을 가둬 언제나 외톨이 맘의 문을 닫고 슬픔을 등에 지고 살아가는 바보 두 눈을 감고 두 귀를 막고 캄캄한 어둠속에 내 자신을 가둬 아무도 모르게 다가온 이별에 대면했을때 또 다시 혼자가 되는게 두려워 외면했었네 꿈에도 그리던 지나간 시간이 다시금 내게로 되돌아오기를 바라며 간절한 맘으로 밤마다 기도했었네 시위를 당기고 내 손을 떠나간 추억의 화살이 머나먼 과녁을 향해서 한없이 빠르게 날아가 내게로 돌아와 달라고 내 손을 붙잡아 달라고 부르고 불러도 한없이 소리쳐 대봐도 아무런 대답이 없는 널 내 기억 속에서 너라는 사람의 존재를 완전히 지우려 끝없이 몸부림쳐 봐도 매일밤 꿈에서 그대가 나타나 흐르는 눈물을 닦아주는걸 나 어떡하라고 다 끄떡없다고 거짓말 하라고 더는 못 참겠다고 나도 아플 땐 아프다고 슬플땐 슬프다고 얼어 붙은 심장이 자꾸만 내게로 고자질해 정말로 끝이라고 정말로 괜찮다고 꾹 참고 참았던 눈물이 자꾸만 내게로 쏟아지네 상처를 치료해줄 사람 어디 없나 가만히 놔두다간 끊임없이 덧나 사랑도 사람도 너무나도 겁나 혼자인게 무서워 난 잊혀질까 두려워 상처를 치료해줄 사람 어디 없나 가만히 놔두다간 끊임없이 덧나 사랑도 사람도 너무나도 겁나 혼자인게 무서워 난 잊혀질까 두려워 언제나 외톨이 맘의 문을 닫고 슬픔을 등에 지고 살아가는 바보 두 눈을 감고 두 귀를 막고 캄캄한 어둠속에 내 자신을 가둬 언제나 외톨이 맘의 문을 닫고 슬픔을 등에 지고 살아가는 바보 두 눈을 감고 두 귀를 막고 캄캄한 어둠속에 내 자신을 가둬")
# Out:
# 상처를 치료해줄 사람 어디 없나 가만히 놔두다간 끊임없이 덧나 사랑도 사람도 너무나도 겁나 혼자인게 무서워 난 잊혀질까 두려워 상처를 치료해줄 사람 어디 없나 가만히 놔두다간 끊임없이 덧나 사랑도 사람도 너무나도 겁나 혼자인게 무서워 난 잊혀질까 두려워 언제나 외톨이 맘의 문을 닫고 슬픔을 등에 지고 살아가는 바보 두 눈을 감고 두 귀를 막고 캄캄한 어둠속에 내 자신을 가둬 365일 1년 내내 방황하는 내 영혼의 조작 키를 잡은 Jack Sparrow 몰아치는 Hurricane 졸라매는 허리끈에 방향감을 상실하고 길을 잃은 소리꾼 내 안에 숨어 있는 또 다른 나와 싸워 그녀가 떠나갈때 내게 말했었지 너는 곁에 있어도 있는 게 아닌것 같다고 만지면 베어버리는 칼날같은 사람 심장이 얼어붙은 차가웠던 사랑 그래 1분 1초가 사는게 사는게 아냐 매일 매일이 너무나 두려워 Maider누가 날 좀 꺼내줘 언제나 외톨이 맘의 문을 닫고 슬픔을 등에 지고 살아가는 바보 두 눈을 감고 두 귀를 막고 캄캄한 어둠속에 내 자신을 가둬 언제나 외톨이 맘의 문을 닫고 슬픔을 등에 지고 살아가는 바보 두 눈을 감고 두 귀를 막고 캄캄한 어둠속에 내 자신을 가둬 아무도 모르게 다가온 이별에 대면했을때 또 다시 혼자가 되는게 두려워 외면했었네 꿈에도 그리던 지나간 시간이 다시금 내게로 되돌아오기를 바라며 간절한 맘으로 밤마다 기도했었네 시위를 당기고 내 손을 떠나간 추억의 화살이 머나먼 과녁을 향해서 한없이 빠르게 날아가 내게로 돌아와 달라고 내 손을 붙잡아 달라고 부르고 불러도 한없이 소리쳐 대봐도 아무런 대답이 없는 널 내 기억 속에서 너라는 사람의 존재를 완전히 지우려 끝없이 몸부림쳐 봐도 매일밤 꿈에서 그대가 나타나 흐르는 눈물을 닦아주는걸 나 어떡하라고 다 끄떡없다고 거짓말 하라고 더는 못 참겠다고 나도 아플 땐 아프다고 슬플땐 슬프다고 얼어 붙은 심장이 자꾸만 내게로 고자질해 정말로 끝이라고 정말로 괜찮다고 꾹 참고 참았던 눈물이 자꾸만 내게로 쏟아지네 상처를 치료해줄 사람
# ...

# %%
df.loc[:3]
# Out:
#       메뉴      가격    칼로리
# 0  아메리카노  4500.0   10.0
# 1   카페라떼  5000.0  110.0
# 2   카페모카  5500.0  250.0
# 3   카푸치노  5000.0  110.0

# %%
df.iloc[:3]
# Out:
#       메뉴      가격    칼로리
# 0  아메리카노  4500.0   10.0
# 1   카페라떼  5000.0  110.0
# 2   카페모카  5500.0  250.0

# %%
df[['메뉴','칼로리']]
# Out:
#       메뉴    칼로리
# 0  아메리카노   10.0
# 1   카페라떼  110.0
# 2   카페모카  250.0
# 3   카푸치노  110.0
# 4  에스프레소   20.0
# 5    밀크티  210.0
# 6     녹차    0.0

# %%
df.iloc[2:4, '메뉴':'칼로리']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-97-d48b61dd8f45> in <cell line: 0>()
# ----> 1 df.iloc[2:4, '메뉴':'칼로리']
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1182             if self._is_scalar_access(key):
#    1183                 return self.obj._get_value(*key, takeable=self._takeable)
# -> 1184             return self._getitem_tuple(key)
#    1185         else:
#    1186             # we by definition only have the 0th axis
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexing.py in _getitem_tuple(self, tup)
#    1692             return self._getitem_lowerdim(tup)
#    1693
# -> 1694         return self._getitem_tuple_same_dim(tup)
#    1695
#    1696     def _get_list_axis(self, key, axis: AxisInt):
#
# ...

# %%
df.loc[2:4, '메뉴':'칼로리']
# Out:
#       메뉴      가격    칼로리
# 2   카페모카  5500.0  250.0
# 3   카푸치노  5000.0  110.0
# 4  에스프레소  4000.0   20.0

# %%
df.iloc[2:5,0:3]
# Out:
#       메뉴      가격    칼로리
# 2   카페모카  5500.0  250.0
# 3   카푸치노  5000.0  110.0
# 4  에스프레소  4000.0   20.0

# %%
df
# Out:
#       메뉴      가격    칼로리
# 0  아메리카노  4500.0   10.0
# 1   카페라떼  5000.0  110.0
# 2   카페모카  5500.0  250.0
# 3   카푸치노  5000.0  110.0
# 4  에스프레소  4000.0   20.0
# 5    밀크티  5900.0  210.0
# 6     녹차  5300.0    0.0

# %%
df.loc[5:6, '메뉴':'칼로리']
# Out:
#     메뉴      가격    칼로리
# 5  밀크티  5900.0  210.0
# 6   녹차  5300.0    0.0

# %%
df.iloc[5:7, [0,2]]
# Out:
#     메뉴    칼로리
# 5  밀크티  210.0
# 6   녹차    0.0

# %%
df.loc[[0,4], '메뉴':'칼로리']
# Out:
#       메뉴      가격   칼로리
# 0  아메리카노  4500.0  10.0
# 4  에스프레소  4000.0  20.0

# %%
df.iloc[[0,4], [0,2]]
# Out:
#       메뉴   칼로리
# 0  아메리카노  10.0
# 4  에스프레소  20.0

# %%
df['할인가']=0

# %%
df
# Out:
#       메뉴      가격    칼로리  할인가
# 0  아메리카노  4500.0   10.0    0
# 1   카페라떼  5000.0  110.0    0
# 2   카페모카  5500.0  250.0    0
# 3   카푸치노  5000.0  110.0    0
# 4  에스프레소  4000.0   20.0    0
# 5    밀크티  5900.0  210.0    0
# 6     녹차  5300.0    0.0    0

# %%
df['할인가']=df['가격']*0.8

# %%
df
# Out:
#       메뉴      가격    칼로리   할인가
# 0  아메리카노  4500.0   10.0  3600
# 1   카페라떼  5000.0  110.0  4000
# 2   카페모카  5500.0  250.0  4400
# 3   카푸치노  5000.0  110.0  4000
# 4  에스프레소  4000.0   20.0  3200
# 5    밀크티  5900.0  210.0  4720
# 6     녹차  5300.0    0.0  4240

# %%
df['할인가']=df['할인가'].astype('int')

# %%
df['원산지']=['콜롬비아','중국','과테말라','과테말라','콜림비아','한국','일본']

# %%
df
# Out:
#       메뉴      가격    칼로리   할인가   원산지
# 0  아메리카노  4500.0   10.0  3600  콜롬비아
# 1   카페라떼  5000.0  110.0  4000    중국
# 2   카페모카  5500.0  250.0  4400  과테말라
# 3   카푸치노  5000.0  110.0  4000  과테말라
# 4  에스프레소  4000.0   20.0  3200  콜림비아
# 5    밀크티  5900.0  210.0  4720    한국
# 6     녹차  5300.0    0.0  4240    일본

# %%
df.loc[1,'원산지']='중국'
df
# Out:
#       메뉴      가격    칼로리   할인가   원산지
# 0  아메리카노  4500.0   10.0  3600  콜롬비아
# 1   카페라떼  5000.0  110.0  4000    중국
# 2   카페모카  5500.0  250.0  4400  과테말라
# 3   카푸치노  5000.0  110.0  4000  과테말라
# 4  에스프레소  4000.0   20.0  3200  콜림비아
# 5    밀크티  5900.0  210.0  4720    한국
# 6     녹차  5300.0    0.0  4240    일본

# %%
df.loc[7]=['코코아',5000,310,int(5000*0.8),'미국']

# %%
df
# Out:
#       메뉴      가격    칼로리   할인가   원산지
# 0  아메리카노  4500.0   10.0  3600  콜롬비아
# 1   카페라떼  5000.0  110.0  4000    중국
# 2   카페모카  5500.0  250.0  4400  과테말라
# 3   카푸치노  5000.0  110.0  4000  과테말라
# 4  에스프레소  4000.0   20.0  3200  콜림비아
# 5    밀크티  5900.0  210.0  4720    한국
# 6     녹차  5300.0    0.0  4240    일본
# 7    코코아    5000  310.0  4000    미국

# %%
df.loc[8]={'메뉴':'요커트','가격':6000,'칼로리':600,'할인가':4800,'원산지':'북한'}

# %%
df
# Out:
#       메뉴      가격    칼로리   할인가   원산지
# 0  아메리카노  4500.0   10.0  3600  콜롬비아
# 1   카페라떼  5000.0  110.0  4000    중국
# 2   카페모카  5500.0  250.0  4400  과테말라
# 3   카푸치노  5000.0  110.0  4000  과테말라
# 4  에스프레소  4000.0   20.0  3200  콜림비아
# 5    밀크티  5900.0  210.0  4720    한국
# 6     녹차  5300.0    0.0  4240    일본
# 7    코코아    5000  310.0  4000    미국
# 8    요커트    6000  600.0  4800    북한

# %%
df.loc['시즌']={'메뉴':'단팥죽','가격':7000,'칼로리':200,'할인가':int(7000*0.8),'원산지':'자메이카'}

# %%
df
# Out:
#        메뉴      가격    칼로리   할인가   원산지
# 0   아메리카노  4500.0   10.0  3600  콜롬비아
# 1    카페라떼  5000.0  110.0  4000    중국
# 2    카페모카  5500.0  250.0  4400  과테말라
# 3    카푸치노  5000.0  110.0  4000  과테말라
# 4   에스프레소  4000.0   20.0  3200  콜림비아
# 5     밀크티  5900.0  210.0  4720    한국
# 6      녹차  5300.0    0.0  4240    일본
# 7     코코아    5000  310.0  4000    미국
# 8     요커트    6000  600.0  4800    북한
# 시즌    단팥죽    7000  200.0  5600  자메이카

# %%
df.to_csv('/content/drive/MyDrive/2302김현호 데이터분석/데이터들/커피2.csv' , index=False)

# %%
df3 = pd.read_csv('/content/drive/MyDrive/2302김현호 데이터분석/데이터들/커피2.csv'  )

# %%
df3
# Out:
#       메뉴      가격    칼로리   할인가   원산지
# 0  아메리카노  4500.0   10.0  3600  콜롬비아
# 1   카페라떼  5000.0  110.0  4000    중국
# 2   카페모카  5500.0  250.0  4400  과테말라
# 3   카푸치노  5000.0  110.0  4000  과테말라
# 4  에스프레소  4000.0   20.0  3200  콜림비아
# 5    밀크티  5900.0  210.0  4720    한국
# 6     녹차  5300.0    0.0  4240    일본
# 7    코코아  5000.0  310.0  4000    미국
# 8    요커트  6000.0  600.0  4800    북한
# 9    단팥죽  7000.0  200.0  5600  자메이카
